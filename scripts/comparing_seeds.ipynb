# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import matplotlib
# For higher resoltion figures
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
plt.rcParams["font.family"] = "Helvetica" #somethings this one doesnt work
plt.rcParams['pdf.fonttype'] = 42

# %%
data = pd.read_csv("/Users/claireleblanc/Documents/grad_school/staller_lab/NN_interpretability_for_AD_prediction/results/results_2.csv")
data
# Out:
#                                             model_name         model_type
# 0    ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund  \
# 1    ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 2    ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 3    ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 4    ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# ..                                                 ...                ...
# 803  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 804  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 805  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 806  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 807  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
#
#       kernel_size  activity_fun   negative_pen   weight_pen   activity_weight
# 0               4          Hill            0.1          0.1               1.0  \
# 1               5          Hill            0.1          0.1               1.0
# 2               6          Hill            0.1          0.1               1.0
# 3               7          Hill            0.1          0.1               1.0
# 4               8          Hill            0.1          0.1               1.0
# ..            ...           ...            ...          ...               ...
# 803            20          Hill            0.1          0.1               1.0
# 804            30          Hill            0.1          0.1               1.0
# 805            40          Hill            0.1          0.1               1.0
# 806             5          Hill            0.1          0.1               1.0
# 807            10          Hill            0.1          0.1               1.0
#
#       hill_value   Rsq_abund_val  Rs1_act_val  ...  Unnamed: 31  Unnamed: 32
# 0            1.0        0.293811     0.681682  ...          NaN          NaN  \
# 1            1.0        0.307472     0.699772  ...          NaN          NaN
# 2            1.0        0.312843     0.697321  ...          NaN          NaN
# 3            1.0        0.304789     0.724118  ...          NaN          NaN
# 4            1.0        0.308985     0.719788  ...          NaN          NaN
# ..           ...             ...          ...  ...          ...          ...
# 803          1.0        0.291001     0.648178  ...          NaN          NaN
# 804          1.0        0.291001     0.607161  ...          NaN          NaN
# 805          1.0        0.291001     0.693401  ...          NaN          NaN
# 806          1.0        0.306614     0.647380  ...          NaN          NaN
# 807          1.0        0.306614     0.617702  ...          NaN          NaN
#
#      Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36 Unnamed: 37
# 0            NaN          NaN          NaN          NaN         NaN  \
# 1            NaN          NaN          NaN          NaN         NaN
# 2            NaN          NaN          NaN          NaN         NaN
# 3            NaN          NaN          NaN          NaN         NaN
# 4            NaN          NaN          NaN          NaN         NaN
# ..           ...          ...          ...          ...         ...
# 803          NaN          NaN          NaN          NaN         NaN
# 804          NaN          NaN          NaN          NaN         NaN
# 805          NaN          NaN          NaN          NaN         NaN
# 806          NaN          NaN          NaN          NaN         NaN
# 807          NaN          NaN          NaN          NaN         NaN
#
#     Unnamed: 38 Unnamed: 39 Unnamed: 40
# 0           NaN         NaN         NaN
# 1           NaN         NaN         NaN
# 2           NaN         NaN         NaN
# 3           NaN         NaN         NaN
# 4           NaN         NaN         NaN
# ..          ...         ...         ...
# 803         NaN         NaN         NaN
# 804         NaN         NaN         NaN
# 805         NaN         NaN         NaN
# 806         NaN         NaN         NaN
# 807         NaN         NaN         NaN
#
# [808 rows x 41 columns]

# %%
data_w_seed = data[["seed" in s for s in data["model_name"]]]
data_w_seed
# Out:
#                                             model_name         model_type
# 448  ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund  \
# 449  ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 450  ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 451  ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# 452  ../model_data/three_state_abundmodel_b10_e200_...  three_state_abund
# ..                                                 ...                ...
# 803  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 804  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 805  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 806  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
# 807  ../model_data/two_state_abundmodel_b10_e200_L0...    two_state_abund
#
#       kernel_size  activity_fun   negative_pen   weight_pen   activity_weight
# 448             4          Hill            0.1          0.5               1.0  \
# 449             5          Hill            0.1          0.5               1.0
# 450             6          Hill            0.1          0.5               1.0
# 451             7          Hill            0.1          0.5               1.0
# 452             8          Hill            0.1          0.5               1.0
# ..            ...           ...            ...          ...               ...
# 803            20          Hill            0.1          0.1               1.0
# 804            30          Hill            0.1          0.1               1.0
# 805            40          Hill            0.1          0.1               1.0
# 806             5          Hill            0.1          0.1               1.0
# 807            10          Hill            0.1          0.1               1.0
#
#       hill_value   Rsq_abund_val  Rs1_act_val  ...  Unnamed: 31  Unnamed: 32
# 448          1.0        0.298536     0.683073  ...          NaN          NaN  \
# 449          1.0        0.298536     0.690635  ...          NaN          NaN
# 450          1.0        0.298536     0.707415  ...          NaN          NaN
# 451          1.0        0.298536     0.678459  ...          NaN          NaN
# 452          1.0        0.298536     0.683929  ...          NaN          NaN
# ..           ...             ...          ...  ...          ...          ...
# 803          1.0        0.291001     0.648178  ...          NaN          NaN
# 804          1.0        0.291001     0.607161  ...          NaN          NaN
# 805          1.0        0.291001     0.693401  ...          NaN          NaN
# 806          1.0        0.306614     0.647380  ...          NaN          NaN
# 807          1.0        0.306614     0.617702  ...          NaN          NaN
#
#      Unnamed: 33  Unnamed: 34  Unnamed: 35  Unnamed: 36 Unnamed: 37
# 448          NaN          NaN          NaN          NaN         NaN  \
# 449          NaN          NaN          NaN          NaN         NaN
# 450          NaN          NaN          NaN          NaN         NaN
# 451          NaN          NaN          NaN          NaN         NaN
# 452          NaN          NaN          NaN          NaN         NaN
# ..           ...          ...          ...          ...         ...
# 803          NaN          NaN          NaN          NaN         NaN
# 804          NaN          NaN          NaN          NaN         NaN
# 805          NaN          NaN          NaN          NaN         NaN
# 806          NaN          NaN          NaN          NaN         NaN
# 807          NaN          NaN          NaN          NaN         NaN
#
#     Unnamed: 38 Unnamed: 39 Unnamed: 40
# 448         NaN         NaN         NaN
# 449         NaN         NaN         NaN
# 450         NaN         NaN         NaN
# 451         NaN         NaN         NaN
# 452         NaN         NaN         NaN
# ..          ...         ...         ...
# 803         NaN         NaN         NaN
# 804         NaN         NaN         NaN
# 805         NaN         NaN         NaN
# 806         NaN         NaN         NaN
# 807         NaN         NaN         NaN
#
# [360 rows x 41 columns]

# %%
three_state_abund = data[data[" model_type"] == "three_state_abund"]
plt.scatter(three_state_abund[" kernel_size"], three_state_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)

# %%
import re

# %%
data_abund = pd.read_csv("/Users/claireleblanc/Documents/grad_school/staller_lab/NN_interpretability_for_AD_prediction/results/results_abund_repeats.csv")

pattern = r"_ak(\d+)_"
data_abund["abund_kernel_size"] = [re.search(pattern, name).group(1) for name in data_abund["model_name"]]
plt.scatter(data_abund[" kernel_size"], data_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)

plt.xlabel("Convolutional filter size")
plt.ylabel("Activity pearson correlation")

axs = plt.gca()
axs.spines["top"].set_visible(False)
axs.spines["right"].set_visible(False)

# %%
fig, axs = plt.subplots(2,1, sharex=True, figsize=(5,5))
axs[0].scatter(data_abund["abund_kernel_size"], data_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)
axs[1].scatter(data_abund["abund_kernel_size"], data_abund[" Rsq_abund_val"], label="Three state NN", s=8, alpha=0.5)

# %%
plt.scatter(data_abund[" Rsq_abund_val"], data_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)

# %%
three_state_abund = data[data[" model_type"] == "three_state_abund"]
two_state_abund = data[data[" model_type"] == "two_state_abund"]
simple_act = data[data[" model_type"] == "simple_act"]
simple_abund = data[data[" model_type"] == "simple_abund"]

# %%
plt.scatter(simple_act[" kernel_size"], simple_act["Rs1_act_val"], label="Simple NN", s=8, alpha=0.5)
plt.scatter(two_state_abund[" kernel_size"], two_state_abund["Rs1_act_val"], label="Two state NN", s=8, alpha=0.5)
plt.scatter(three_state_abund[" kernel_size"], three_state_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)

plt.ylim(0.5, 0.8)
plt.legend()

axs = plt.gca()
axs.spines["top"].set_visible(False)
axs.spines["right"].set_visible(False)

plt.xlabel("Convolutional Filter Size")
plt.ylabel("Pearson activity correlation")
# Out:
# Text(0, 0.5, 'Pearson activity correlation')

# %%
plt.scatter(two_state_abund[" Rsq_abund_val"], two_state_abund["Rs1_act_val"], label="Two state NN", s=8, alpha=0.5)
plt.scatter(three_state_abund[" Rsq_abund_val"], three_state_abund["Rs1_act_val"], label="Three state NN", s=8, alpha=0.5)

plt.ylim(0.5, 0.8)
plt.legend()

axs = plt.gca()
axs.spines["top"].set_visible(False)
axs.spines["right"].set_visible(False)

plt.xlabel("Pearson abundance correlation")
plt.ylabel("Pearson activity correlation")
# Out:
# Text(0, 0.5, 'Pearson activity correlation')

# %%
plt.scatter(simple_act[" kernel_size"], simple_act["Rs1_act_val"], label="Simple NN", s=8, alpha=0.5)
plt.scatter(simple_abund[" kernel_size"], simple_abund[" Rsq_abund_val"], label="Two state NN", s=8, alpha=0.5)

plt.ylim(0.1, 0.8)
plt.legend()

axs = plt.gca()
axs.spines["top"].set_visible(False)
axs.spines["right"].set_visible(False)

plt.xlabel("Convolutional Filter Size")
plt.ylabel("Pearson activity correlation")
# Out:
# Text(0, 0.5, 'Pearson activity correlation')
